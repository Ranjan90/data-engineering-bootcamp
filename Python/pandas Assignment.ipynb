# %% [markdown]
# Q1. How do you load a CSV file into a Pandas DataFrame?

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# Q2. How do you check the data type of a column in a Pandas DataFrame?

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Q3. How do you select rows from a Pandas DataFrame based on a condition?

# %%
rslt_df = df[df['Age'] > 20]
display(rslt_df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 884      0   SOTON/OQ 392076   7.0500   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [535 rows x 12 columns]

# %% [markdown]
# Q4. How do you rename columns in a Pandas DataFrame?

# %%
rslt_df.rename(columns = {'Pclass':'PassengerClass'}, inplace = True)
display(rslt_df)
# Out:
# /tmp/ipykernel_77/2811282741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rslt_df.rename(columns = {'Pclass':'PassengerClass'}, inplace = True)
#      PassengerId  Survived  PassengerClass  \
# 0              1         0               3
# 1              2         1               1
# 2              3         1               3
# 3              4         1               1
# 4              5         0               3
# ..           ...       ...             ...
# 884          885         0               3
# 885          886         0               3
# 886          887         0               2
# 889          890         1               1
# 890          891         0               3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 884      0   SOTON/OQ 392076   7.0500   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [535 rows x 12 columns]

# %% [markdown]
# Q5. How do you drop columns in a Pandas DataFrame?

# %%
test1=rslt_df.drop("Parch", axis='columns')
display(test1)
# Out:
#      PassengerId  Survived  PassengerClass  \
# 0              1         0               3
# 1              2         1               1
# 2              3         1               3
# 3              4         1               1
# 4              5         0               3
# ..           ...       ...             ...
# 884          885         0               3
# 885          886         0               3
# 886          887         0               2
# 889          890         1               1
# 890          891         0               3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 4              373450   8.0500   NaN        S
# ..                ...      ...   ...      ...
# 884   SOTON/OQ 392076   7.0500   NaN        S
# 885            382652  29.1250   NaN        Q
# 886            211536  13.0000   NaN        S
# 889            111369  30.0000  C148        C
# 890            370376   7.7500   NaN        Q
#
# [535 rows x 11 columns]

# %% [markdown]
# Q6. How do you find the unique values in a column of a Pandas DataFrame?

# %%
test1['Survived'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# Q7. How do you find the number of missing values in each column of a Pandas DataFrame?

# %%
test1.isnull().sum()
# Out:
# PassengerId         0
# Survived            0
# PassengerClass      0
# Name                0
# Sex                 0
# Age                 0
# SibSp               0
# Ticket              0
# Fare                0
# Cabin             379
# Embarked            2
# dtype: int64

# %% [markdown]
# Q8. How do you fill missing values in a Pandas DataFrame with a specific value?

# %%
test1.fillna(0, inplace=True)
test1.isnull()
# Out:
#      PassengerId  Survived  PassengerClass   Name    Sex    Age  SibSp  \
# 0          False     False           False  False  False  False  False
# 1          False     False           False  False  False  False  False
# 2          False     False           False  False  False  False  False
# 3          False     False           False  False  False  False  False
# 4          False     False           False  False  False  False  False
# ..           ...       ...             ...    ...    ...    ...    ...
# 884        False     False           False  False  False  False  False
# 885        False     False           False  False  False  False  False
# 886        False     False           False  False  False  False  False
# 889        False     False           False  False  False  False  False
# 890        False     False           False  False  False  False  False
#
#      Ticket   Fare  Cabin  Embarked
# 0     False  False  False     False
# 1     False  False  False     False
# 2     False  False  False     False
# 3     False  False  False     False
# 4     False  False  False     False
# ..      ...    ...    ...       ...
# 884   False  False  False     False
# 885   False  False  False     False
# 886   False  False  False     False
# 889   False  False  False     False
# 890   False  False  False     False
#
# [535 rows x 11 columns]

# %% [markdown]
# Q9. How do you concatenate two Pandas DataFrames?

# %%
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
   
# Define a dictionary containing employee data 
data2 = {'Name':['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'], 
        'Age':[17, 14, 12, 52], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
 
# Convert the dictionary into DataFrame  
df1 = pd.DataFrame(data1,index=[0, 1, 2, 3])
 
# Convert the dictionary into DataFrame  
df2 = pd.DataFrame(data2, index=[4, 5, 6, 7])

#using concat method
frames = [df1, df2]
res1 = pd.concat(frames)
res1
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %% [markdown]
# Q10. How do you merge two Pandas DataFrames on a specific column?

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})

df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})

res=df1.merge(df2, left_on='lkey', right_on='rkey')
display(res)
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7

# %% [markdown]
# Q11. How do you group data in a Pandas DataFrame by a specific column and apply an aggregation function?

# %%
# GroupBy
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'],
        'Age':[27, 24, 22, 32,
               33, 36, 27, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd',
                         'B.Tech', 'B.com', 'Msc', 'MA']}
df = pd.DataFrame(data1)
df3=df.groupby(['Name']).sum()
df3
# Out:
# /tmp/ipykernel_77/1050871318.py:11: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3=df.groupby(['Name']).sum()
#         Age
# Name
# Abhi     32
# Anuj     60
# Gaurav   33
# Jai      49
# Princi   59

# %% [markdown]
# Q12. How do you pivot a Pandas DataFrame?

# %%
pivotdf = pd.DataFrame({
       "lev1": [1, 1, 1, 2, 2, 2],
       "lev2": [1, 1, 2, 1, 1, 2],
       "lev3": [1, 2, 1, 2, 1, 2],
       "lev4": [1, 2, 3, 4, 5, 6],
       "values": [0, 1, 2, 3, 4, 5]})

pivotdf.pivot(index="lev1", columns=["lev2", "lev3"],values="values")
# Out:
# lev2    1         2
# lev3    1    2    1    2
# lev1
# 1     0.0  1.0  2.0  NaN
# 2     4.0  3.0  NaN  5.0

# %% [markdown]
# Q13. How do you change the data type of a column in a Pandas DataFrame?

# %%
import pandas as pd
import numpy as np

#initialize a dataframe
df = pd.DataFrame(
	[[21, 72, 67],
	[23, 78, 62],
	[32, 74, 54],
	[52, 54, 76]],
	columns=['a', 'b', 'c'])

print('Previous Datatypes\n', df.dtypes, sep='') 

#change datatype of column
df = df.astype({'a': np.float, 'b': np.int8})

#print results
print('\nNew Datatypes\n', df.dtypes, sep='') 
print('\nDataFrame\n', df, sep='')
# Out:
# Previous Datatypes
# a    int64
# b    int64
# c    int64
# dtype: object
#
# New Datatypes
# a    float64
# b       int8
# c      int64
# dtype: object
#
# DataFrame
#       a   b   c
# 0  21.0  72  67
# 1  23.0  78  62
# 2  32.0  74  54
# 3  52.0  54  76
# /tmp/ipykernel_70/567092760.py:15: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df = df.astype({'a': np.float, 'b': np.int8})

# %% [markdown]
# Q14. How do you sort a Pandas DataFrame by a specific column?

# %%
df_sort = pd.DataFrame({
    'col1': ['A', 'E', 'B', np.nan, 'D', 'C'],
    'col2': [2, 1, 9, 8, 7, 4],
    'col3': [0, 1, 9, 4, 2, 3],
    'col4': ['a', 'B', 'c', 'D', 'e', 'F']
})
df_sort.sort_values(by=['col1'],ascending=True)
# Out:
#   col1  col2  col3 col4
# 0    A     2     0    a
# 2    B     9     9    c
# 5    C     4     3    F
# 4    D     7     2    e
# 1    E     1     1    B
# 3  NaN     8     4    D

# %% [markdown]
# Q15. How do you create a copy of a Pandas DataFrame?

# %%
df= pd.DataFrame({
    'col1': ['A', 'E', 'B', np.nan, 'D', 'C'],
    'col2': [2, 1, 9, 8, 7, 4],
    'col3': [0, 1, 9, 4, 2, 3],
    'col4': ['a', 'B', 'c', 'D', 'e', 'F']
})
#deep copy
d=df.copy()
#shallow copy
s=df.copy(deep=False)

# %% [markdown]
# Q16. How do you filter rows of a Pandas DataFrame by multiple conditions?

# %%
df = pd.DataFrame(np.array(([1, 2, 3], [4, 5, 6])),
                  index=['mouse', 'rabbit'],
                  columns=['one', 'two', 'three'])
df.filter(items=['one', 'three'])
# Out:
#         one  three
# mouse     1      3
# rabbit    4      6

# %% [markdown]
# Q17. How do you calculate the mean of a column in a Pandas DataFrame?

# %%
df = pd.DataFrame(np.array(([1, 2, 3], [4, 5, 6])),
                  columns=['one', 'two','three'])
df["two"].mean()
# Out:
# 3.5

# %% [markdown]
# Q18. How do you calculate the standard deviation of a column in a Pandas DataFrame?

# %%
df = pd.DataFrame(np.array(([1, 2, 3], [4, 5, 6])),
                  columns=['one', 'two','three'])
df["two"].std()
# Out:
# 2.1213203435596424

# %% [markdown]
# Q19. How do you calculate the correlation between two columns in a Pandas DataFrame?

# %%
df = pd.DataFrame(np.array(([1, 2, 3], [4, 5, 6])),
                  columns=['one', 'two','three'])
df.corr()
# Out:
#        one  two  three
# one    1.0  1.0    1.0
# two    1.0  1.0    1.0
# three  1.0  1.0    1.0

# %% [markdown]
# Q20. How do you select specific columns in a DataFrame using their labels?

# %%
df = pd.DataFrame(np.array(([1, 2, 3], [4, 5, 6])),
                  columns=['one', 'two','three'])
df[['one','three']]
# Out:
#    one  three
# 0    1      3
# 1    4      6

# %% [markdown]
# Q21. How do you select specific rows in a DataFrame using their indexes?

# %%
mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
          {'a': 100, 'b': 200, 'c': 300, 'd': 400},
          {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]
df = pd.DataFrame(mydict)
df.iloc[[0]]
# Out:
#    a  b  c  d
# 0  1  2  3  4

# %% [markdown]
# Q22. How do you sort a DataFrame by a specific column?

# %%
df = pd.DataFrame({
    'col1': [10, 8, 6, 3, 9,15],
    'col2': [2, 1, 9, 8, 7, 4],
    'col3': [0, 1, 9, 4, 2, 3],
   
})
df.sort_values(by=['col1'])
# Out:
#    col1  col2  col3
# 3     3     8     4
# 2     6     9     9
# 1     8     1     1
# 4     9     7     2
# 0    10     2     0
# 5    15     4     3

# %% [markdown]
# Q23. How do you create a new column in a DataFrame based on the values of another column?

# %%
df = pd.DataFrame({
    'col1': [10, 8, 6, 3, 9,15],
    'col2': [2, 1, 9, 8, 7, 4],
    'col3': [0, 1, 9, 4, 2, 3],
   
})
df["col4"] = df["col1"] * 2
df
# Out:
#    col1  col2  col3  col4
# 0    10     2     0    20
# 1     8     1     1    16
# 2     6     9     9    12
# 3     3     8     4     6
# 4     9     7     2    18
# 5    15     4     3    30

# %% [markdown]
# Q24. How do you remove duplicates from a DataFrame?

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
})
df.drop_duplicates()
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %% [markdown]
# Q25. What is the difference between .loc and .iloc in Pandas?

# %% [markdown]
# The main distinction between the two methods is:
# loc gets rows (and/or columns) with particular labels.
# iloc gets rows (and/or columns) at integer locations.

# %%
df = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
     index=['cobra', 'viper', 'sidewinder'],
     columns=['max_speed', 'shield'])
df.loc['viper']
# Out:
# max_speed    4
# shield       5
# Name: viper, dtype: int64

# %% [markdown]
# iloc example

# %%
mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
          {'a': 100, 'b': 200, 'c': 300, 'd': 400},
          {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]
df = pd.DataFrame(mydict)
df.iloc[[0, 1]]
# Out:
#      a    b    c    d
# 0    1    2    3    4
# 1  100  200  300  400
